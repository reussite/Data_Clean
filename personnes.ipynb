# %%
import pandas as  pd
import numpy as np

# %%
data = pd.read_csv('https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/7410486/personnes.csv')
print(data)
# Out:
#    prenom                                   email date_naissance  \
# 0   Leila                       leila@example.com     23/01/1990
# 1  Samuel                  samuel_329@example.com     20/09/2001
# 2   Radia                choupipoune@supermail.eu  12 sept. 1984
# 3    Marc  marco23@example.com, mc23@supermail.eu     10/02/1978
# 4    Heri                 helloworld@supermail.eu     05/03/2008
# 5   Hanna                  hanna2019@supermail.eu     01/01/1970
# 6  samuël                  samuel_329@example.com            NaN
#
#             pays taille
# 0         France  1.49m
# 1            NaN  1.67m
# 2  Côte d'ivoire  153cm
# 3         France  1.65m
# 4     Madagascar  1.34m
# 5             24  3.45m
# 6          Bénin  1.45m

# %%
data.isnull().sum()
data
# Out:
#    prenom                                   email date_naissance  \
# 0   Leila                       leila@example.com     23/01/1990
# 1  Samuel                  samuel_329@example.com     20/09/2001
# 2   Radia                choupipoune@supermail.eu  12 sept. 1984
# 3    Marc  marco23@example.com, mc23@supermail.eu     10/02/1978
# 4    Heri                 helloworld@supermail.eu     05/03/2008
# 5   Hanna                  hanna2019@supermail.eu     01/01/1970
# 6  samuël                  samuel_329@example.com            NaN
#
#             pays taille
# 0         France  1.49m
# 1            NaN  1.67m
# 2  Côte d'ivoire  153cm
# 3         France  1.65m
# 4     Madagascar  1.34m
# 5             24  3.45m
# 6          Bénin  1.45m

# %%
duplaicated_mail = data.loc[data['email'].duplicated(keep=False)]
print(duplaicated_mail)

data
# Out:
#    prenom                   email date_naissance   pays taille
# 1  Samuel  samuel_329@example.com     20/09/2001    NaN  1.67m
# 6  samuël  samuel_329@example.com            NaN  Bénin  1.45m
#    prenom                                   email date_naissance  \
# 0   Leila                       leila@example.com     23/01/1990
# 1  Samuel                  samuel_329@example.com     20/09/2001
# 2   Radia                choupipoune@supermail.eu  12 sept. 1984
# 3    Marc  marco23@example.com, mc23@supermail.eu     10/02/1978
# 4    Heri                 helloworld@supermail.eu     05/03/2008
# 5   Hanna                  hanna2019@supermail.eu     01/01/1970
# 6  samuël                  samuel_329@example.com            NaN
#
#             pays taille
# 0         France  1.49m
# 1            NaN  1.67m
# 2  Côte d'ivoire  153cm
# 3         France  1.65m
# 4     Madagascar  1.34m
# 5             24  3.45m
# 6          Bénin  1.45m

# %%
#Traitement des données
VALID_COUNTRIES = [ "France", "Côte d'ivoire", "Madagascar", "Bénin"]
mask = ~data['pays'].isin(VALID_COUNTRIES)
df = data.loc[mask, 'pays'] = np.nan
data
# Out:
#    prenom                                   email date_naissance  \
# 0   Leila                       leila@example.com     23/01/1990
# 1  Samuel                  samuel_329@example.com     20/09/2001
# 2   Radia                choupipoune@supermail.eu  12 sept. 1984
# 3    Marc  marco23@example.com, mc23@supermail.eu     10/02/1978
# 4    Heri                 helloworld@supermail.eu     05/03/2008
# 5   Hanna                  hanna2019@supermail.eu     01/01/1970
# 6  samuël                  samuel_329@example.com            NaN
#
#             pays taille
# 0         France  1.49m
# 1            NaN  1.67m
# 2  Côte d'ivoire  153cm
# 3         France  1.65m
# 4     Madagascar  1.34m
# 5            NaN  3.45m
# 6          Bénin  1.45m

# %%
#Traitement des email
data['email'] = data['email'].str.split(',', n=1, expand=True)[0]
data
# Out:
#    prenom                     email date_naissance           pays taille
# 0   Leila         leila@example.com     23/01/1990         France  1.49m
# 1  Samuel    samuel_329@example.com     20/09/2001            NaN  1.67m
# 2   Radia  choupipoune@supermail.eu  12 sept. 1984  Côte d'ivoire  153cm
# 3    Marc       marco23@example.com     10/02/1978         France  1.65m
# 4    Heri   helloworld@supermail.eu     05/03/2008     Madagascar  1.34m
# 5   Hanna    hanna2019@supermail.eu     01/01/1970            NaN  3.45m
# 6  samuël    samuel_329@example.com            NaN          Bénin  1.45m

# %%
#Travaux pratique 
data_pt = pd.read_csv('https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/7410486/operations.csv')

data_pt
# Out:
#     date_operation                                       libelle  montant  \
# 0       2023-03-31                      DON XX XX XX XX XX XX XX    -1.44
# 1       2023-04-03                           CARTE XX XX RAPT XX   -24.00
# 2       2023-04-03                           CARTE XX XX RAPT XX   -73.00
# 3       2023-04-03  VIREMENT XX XX XX XX XX XX XX XX XX XX XX XX   676.00
# 4       2023-04-03                    VIREMENT XX XX XX XX XX XX     4.80
# ..             ...                                           ...      ...
# 304     2023-10-05                       CARTE XX XX XX XX XX XX   -10.64
# 305     2023-10-05                             CARTE XX XX XX XX    -4.80
# 306     2023-10-06          FORFAIT COMPTE SUPERBANK XX XX XX XX    -1.92
# 307     2023-10-06                       CARTE XX XX CHEZ LUC XX   -10.00
# 308     2023-10-06                PRELEVEMENT XX TELEPHONE XX XX   -13.58
#
#      solde_avt_ope                categ
# ...

# %%
#affichage de la taille du dataset  
data_pt.shape
# Out:
# (309, 5)

# %% [markdown]
# ### 1. Erreurs de Types

# %%
data_pt.dtypes
# Out:
# date_operation     object
# libelle            object
# montant           float64
# solde_avt_ope     float64
# categ              object
# dtype: object

# %% [markdown]
# La variable date_operation est de type object ce qui semble incorrect.
# correction du type avec la méthode to_datetime de pandas:

# %%
data['date_operation'] = pd.to_datetime(data['date_operation'])
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_operation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...
